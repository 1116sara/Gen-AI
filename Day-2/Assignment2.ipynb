# %% [markdown]
# #### **Day 2 Assignment**

# %% [markdown]
# Before Day 3, modify your chatbot to display the token count after every single response:
# ```
# Bot: [response here]
# Tokens used this call: 150
# Total conversation tokens so far: 450
# ```
# You already know exactly where token counts live in the response object. Implement this yourself.
#
# This isn't just an exercise — in Day 3 we go into **Prompt Engineering**, and token awareness becomes critical. Come back when it's done.

# %% [markdown]
# #### **My Response**

# %% [markdown]
# ```python
#  print(f"\nBot: {assistant_reply}\n")
#     print(f"\nTokens used in this call: {response.usage.completion_tokens}")
#     print(f"\nTotal conversation tokens so far: {response.usage.total_tokens}")
# ```

# %% [markdown]
# That's correct. Clean and simple.
#
# Run it and test it — make sure the numbers actually print correctly mid conversation.
#
# One small thing to notice when you run it: look at `total_tokens` across multiple turns. Watch how it grows with each message. That number is the actual tokens sent to the **API in that call** — meaning it includes the entire history you're sending each time, not just the latest message.
#
# Once you've confirmed it works, tell me what you see and we move to Day 3 — Prompt Engineering. That's where your NLP background is going to give you a real advantage over most beginners.

# %% [markdown]
# #### **My Response**

# %% [markdown]
# Chatbot ready. Type 'quit' to exit.
# You: hi I am sara. What areyou?
#
# Bot: Hello Sara. I am an AI assistant, a computer program designed to help users with information and tasks. I'm here to provide you with assistance, answer your questions, and engage in conversation. What's on your mind today?
# Tokens used in this call: 47
# Total conversation tokens so far: 104
#
# You: How are you made?
#
# Bot: I'm a type of artificial intelligence (AI) called a large language model, powered by machine learning algorithms and natural language processing (NLP) techniques. My creation involves a complex process that involves:
# 1. **Data collection**: A massive amount of text data is gathered from various sources, including books, articles, research papers, and websites.
# 2. **Preprocessing**: The collected data is cleaned, tokenized, and formatted into a suitable format for training.
# 3. **Training**: The preprocessed data is fed into a machine learning model, which learns patterns and relationships between words, phrases, and sentences.
# 4. **Model architecture**: A neural network architecture is designed, which includes multiple layers of interconnected nodes (neurons) that process and transform the input data.
# 5. **Training the model**: The model is trained on the massive dataset, using a technique called backpropagation to adjust the model's weights and biases to minimize errors.
# 6. **Fine-tuning**: The trained model is fine-tuned to improve its performance on specific tasks, such as conversational dialogue.
# 7. **Testing and evaluation**: The model is tested on a set of evaluation data to assess its accuracy, fluency, and overall performance.
# 8. **Deployment**: The trained model is deployed as a cloud-based service, allowing users to interact with me through various interfaces, such as this chat platform.
# My architecture is based on a transformer model, which uses self-attention mechanisms to process and understand the context of the input text. This allows me to generate coherent and contextually relevant responses to user queries.
# Keep in mind that my development is an ongoing process, and I'm constantly learning and improving through user interactions and feedback!
# Tokens used in this call: 345
# Total conversation tokens so far: 463

# %% [markdown]
# Working perfectly.
#
# Now look at something interesting in your own output:
# ```
# First call:  Total tokens = 104
# Second call: Total tokens = 463
# ```
# That jumped by 359 tokens in one exchange. The bot gave a long response in turn 2, and now you're carrying all of that in your history for every future call.
#
# This is the cost bloat problem you identified earlier — playing out in real numbers in front of you.
