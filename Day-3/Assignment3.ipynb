# %% [markdown]
# ### **Day-3 Assignment**

# %% [markdown]
# Before Day 4, build a small script that does all of this together:
# ```
# 1. Takes any product review as input
# 2. Classifies sentiment (positive/negative/neutral)
# 3. Returns structured JSON with sentiment,
#    reasoning, confidence and a one line summary
# 4. If confidence < 0.85, print "Flag for human review"
# 5. If confidence >= 0.85, print "Passed to dashboard"
# ```
# This is your first mini real-world pipeline. Build it yourself — you have every piece you need from today. Come back with the code and output.

# %% [markdown]
# more in chat
